# %% [markdown]
# Scenario-Based Teaching: Smart Travel Agent
# 🧑‍🏫 How You Start in Class
#
# Say this:
#
# “Imagine you are very busy and you tell your assistant:
#
# ‘Find me the best flight from Delhi to Mumbai.’
#
# Now instead of replying with just text, your assistant actually thinks,
# checks data, and gives a final decision.”

# %%
def search_flights(source, destination):
    return [
        {"airline": "IndiGo", "price": 4500, "time": "6:00 AM"},
        {"airline": "Air India", "price": 5200, "time": "9:00 AM"}
    ]

def check_weather(city):
    return {"city": city, "temperature": 28, "condition": "Clear"}

def calculate_budget(flights):
    cheapest = min(flights, key=lambda x: x["price"])
    return cheapest

# %%
# Step 2 — Agent Brain (Decision + Planning)
def agent_brain(user_query):
    plan = []

    if "flight" in user_query.lower():
        plan.append("search_flights")
        plan.append("check_weather")
        plan.append("choose_best")

    return plan

# %%
# Step 3 — Execution Engine
def execute_plan(plan):
    context = {}

    for step in plan:
        if step == "search_flights":
            print("\n[Action] Searching Flights...")
            context["flights"] = search_flights("Delhi", "Mumbai")
            print(context["flights"])

        elif step == "check_weather":
            print("\n[Action] Checking Weather...")
            context["weather"] = check_weather("Mumbai")
            print(context["weather"])

        elif step == "choose_best":
            print("\n[Action] Choosing Best Option...")
            best = calculate_budget(context["flights"])
            context["best_flight"] = best
            print(best)

    return context

# %%
# Step 4 — Full Agent
def travel_agent(user_query):
    print("User Query:", user_query)

    # Step 1: Plan
    plan = agent_brain(user_query)
    print("\n[Plan]", plan)

    # Step 2: Execute
    result = execute_plan(plan)

    # Step 3: Final Response
    final_output = f"""
Best Flight: {result['best_flight']['airline']} at ₹{result['best_flight']['price']}
Weather: {result['weather']['condition']}, {result['weather']['temperature']}°C
Recommendation: Book the cheapest early flight.
"""
    return final_output

# %%
# Step 5 — Run It
response = travel_agent("Find best flight from Delhi to Mumbai")
print("\nFinal Answer:\n", response)
# Out:
# User Query: Find best flight from Delhi to Mumbai
#
# [Plan] ['search_flights', 'check_weather', 'choose_best']
#
# [Action] Searching Flights...
# [{'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}, {'airline': 'Air India', 'price': 5200, 'time': '9:00 AM'}]
#
# [Action] Checking Weather...
# {'city': 'Mumbai', 'temperature': 28, 'condition': 'Clear'}
#
# [Action] Choosing Best Option...
# {'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}
#
# Final Answer:
#
# Best Flight: IndiGo at ₹4500
# Weather: Clear, 28°C
# Recommendation: Book the cheapest early flight.

# %% [markdown]
# Scenario: Smart Shopping Assistant 🛒
# You say to your students:
# “Imagine you are planning a party and you tell your assistant:
# ‘Find me the best chocolate cake under ₹500.’
# Now instead of just replying with text, your assistant actually thinks, checks different bakery websites, compares prices, and then gives you the final decision.”

# %%
def search_cakes():
    return [
        {"bakery": "Sweet Treats", "price": 450, "rating": 4.5},
        {"bakery": "Cake World", "price": 550, "rating": 4.7},
        {"bakery": "Bake Bliss", "price": 400, "rating": 4.2},
        {"bakery": "Chocolate Heaven", "price": 480, "rating": 4.8}
    ]

def filter_budget(cakes, max_price):
    return [cake for cake in cakes if cake["price"] <= max_price]

def choose_best(cakes):
    return max(cakes, key=lambda x: x["rating"])

def agent_brain(user_query):
    plan = []

    if "cake" in user_query.lower():
        plan.append("search_cakes")
        plan.append("filter_budget")
        plan.append("choose_best")

    return plan

def execute_plan(plan, budget):
    context = {}

    for step in plan:
        if step == "search_cakes":
            print("\n[Action] Searching Cakes...")
            context["cakes"] = search_cakes()
            print(context["cakes"])

        elif step == "filter_budget":
            print("\n[Action] Filtering by Budget...")
            context["filtered"] = filter_budget(context["cakes"], budget)
            print(context["filtered"])

        elif step == "choose_best":
            print("\n[Action] Choosing Best Cake...")
            best = choose_best(context["filtered"])
            context["best_cake"] = best
            print(best)

    return context

def shopping_agent(user_query, budget):
    print("User Query:", user_query)

    plan = agent_brain(user_query)
    print("\n[Plan]", plan)

    result = execute_plan(plan, budget)

    final_output = f"""
Best Cake: {result['best_cake']['bakery']}
Price: ₹{result['best_cake']['price']}
Rating: {result['best_cake']['rating']}
Recommendation: Best value under your budget.
"""
    return final_output

response = shopping_agent("Find best chocolate cake under 500", 500)
print("\nFinal Answer:\n", response)
# Out:
# User Query: Find best chocolate cake under 500
#
# [Plan] ['search_cakes', 'filter_budget', 'choose_best']
#
# [Action] Searching Cakes...
# [{'bakery': 'Sweet Treats', 'price': 450, 'rating': 4.5}, {'bakery': 'Cake World', 'price': 550, 'rating': 4.7}, {'bakery': 'Bake Bliss', 'price': 400, 'rating': 4.2}, {'bakery': 'Chocolate Heaven', 'price': 480, 'rating': 4.8}]
#
# [Action] Filtering by Budget...
# [{'bakery': 'Sweet Treats', 'price': 450, 'rating': 4.5}, {'bakery': 'Bake Bliss', 'price': 400, 'rating': 4.2}, {'bakery': 'Chocolate Heaven', 'price': 480, 'rating': 4.8}]
#
# [Action] Choosing Best Cake...
# {'bakery': 'Chocolate Heaven', 'price': 480, 'rating': 4.8}
#
# Final Answer:
#
# Best Cake: Chocolate Heaven
# Price: ₹480
# Rating: 4.8
# Recommendation: Best value under your budget.

# %% [markdown]
# Scenario: The University’s AI Plagiarism Agent
# Imagine a university has deployed an AI-powered plagiarism detection agent named PlagiarismLLM.
# Its job is to monitor student essay submissions in real time and decide whether they are original or potentially plagiarized.
#
# Step 1: Thinking (Reasoning)
# Whenever an essay is submitted, PlagiarismLLM first analyzes the text:
# - Example: “Essay contains large verbatim passages from online sources”
# - PlagiarismLLM thinks: “Analyzing essay: multiple verbatim passages detected.”
#
# Step 2: Planning (Choosing an Action)
# Based on the thought, PlagiarismLLM decides which tool to use:
# - If the essay has long verbatim matches or suspicious similarity scores, it plans to flag as potential plagiarism.
# - Otherwise, it plans to mark as original work.
#
# Step 3: Acting (Running Tools)
# PlagiarismLLM hands over the decision to PlagiarismTools, which executes the action:
# - flag_plagiarism → returns “Potential Plagiarism Detected”
# - mark_original → returns “Original Work”
#
# Step 4: Answering (Final Decision)
# Once a clear classification is reached, PlagiarismLLM announces the decision:
# - “Decision: Potential Plagiarism Detected”
# - “Decision: Original Work”

# %%
class PlagiarismLLM:
    def think(self, input_text):
        return f"Analyzing Essay: {input_text}"

    def plan(self, text):
        if "verbatim" in text.lower() or "similarity" in text.lower():
            return "suspicious"
        return "normal"

    def answer(self, obs):
        return f"Decision: {obs}"


class PlagiarismTools:
    def run(self, action):
        if action == "suspicious":
            return "Potential Plagiarism Detected"
        if action == "normal":
            return "Original Work"
        return "Unknown"


def is_final(obs):
    return obs in ["Potential Plagiarism Detected", "Original Work"]


llm = PlagiarismLLM()
tools = PlagiarismTools()


def react_agent(essay, max_steps=3):
    obs = essay

    for _ in range(max_steps):
        text = llm.think(obs)
        action = llm.plan(text)
        obs = tools.run(action)

        if is_final(obs):
            return llm.answer(obs)

    return llm.answer("Could not determine")


print(react_agent("This essay has verbatim"))
print(react_agent("This essay has similarity"))
print(react_agent("This essay is good"))
# Out:
# Decision: Potential Plagiarism Detected
# Decision: Potential Plagiarism Detected
# Decision: Original Work

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()

API_TOKEN = os.getenv('API_KEY_HUGG')
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


def flag_suspicious(transaction):
    return "Suspicious Transaction"


def mark_normal(transaction):
    return "Normal Transaction"


def fraud_agent(transaction: str):
    thought = query_llm(f"Analyze this transaction: {transaction}")
    print("LLM Thought:", thought)

    if "overseas" in transaction.lower() or "multiple deposits" in transaction.lower():
        action = flag_suspicious
    else:
        action = mark_normal

    result = action(transaction)

    final_answer = query_llm(f"Decision: {result}")
    return final_answer


print(fraud_agent("Payment to overseas account"))
# Out:
# LLM Thought: **Transaction Analysis: Payment to Overseas Account**
#
# **Transaction Details:**
#
# * Type: Outbound payment (payment sent from a domestic account to an overseas account)
# * Currency: [Insert currency of the overseas account, e.g., USD, EUR, etc.]
# * Amount: [Insert amount of the payment, e.g., $10,000]
# * Beneficiary: [Insert name of the recipient company or individual]
# * Beneficiary Account: [Insert overseas account number or routing details]
# * Payment Method: [Insert method of payment, e.g., wire transfer, SWIFT, etc.]
# * Date: [Insert date of the payment]
#
# **Risks and Considerations:**
#
# 1. **Currency Exchange Rates:** The payment may incur exchange rate losses or gains depending on the prevailing exchange rates at the time of payment.
# 2. **Transfer Fees:** There may be fees associated with the payment, such as transfer fees, SWIFT fees, or correspondent bank fees.
# 3. **
# **Suspicious Transaction Decision-Making Process**
#
# A suspicious transaction refers to a financial transaction that is unusual or does not conform to a normal pattern, often indicating potential money laundering or other illicit activities. The decision-making process for identifying and reporting suspicious transactions involves the following steps:
#
# ### 1. Transaction Monitoring
#
# *   Regularly review and monitor financial transactions for unusual patterns or anomalies.
# *   Identify red flags such as:
#     *   Large or frequent transactions
#     *   Transactions involving multiple countries or jurisdictions
#     *   Transactions with unknown or unverified parties
#     *   Transactions with unusual payment methods or instruments
#     *   Transactions that involve high-risk industries or activities
#
# ### 2. Risk Assessment
#
# *   Evaluate the risk associated with each transaction based on the identified red flags.
# *   Consider factors such as:
#     *   The type of business or activity involved
#     *   The geographic location of the parties involved
#     *   The amount and frequency of transactions
#     *

# %% [markdown]
# 🏥 Scenario: The Hospital’s AI Appointment Agent
# Imagine a hospital has deployed an AI-powered agent named MediLLM.
# Its job is to monitor patient appointment requests and decide whether the requested slot is available or needs rescheduling.
#
# Step 1 — Thinking (Reasoning)
# Whenever a patient request comes in, MediLLM first analyzes the details:
# - Example: “Request for Dr. Sharma at 10 AM tomorrow”
# - MediLLM thinks: “Analyzing appointment request: Dr. Sharma, 10 AM tomorrow.”
#
# Step 2 — Planning (Choosing an Action)
# Based on the thought, MediLLM decides which tool to use:
# - If the requested slot is free, it plans to confirm appointment.
# - If the slot is already booked, it plans to suggest rescheduling.
#
# Step 3 — Acting (Running Tools)
# MediLLM hands over the decision to AppointmentTools, which executes the action:
# - confirm_slot → returns “Appointment Confirmed”
# - suggest_reschedule → returns “Slot Unavailable, Please Reschedule”
#
# Step 4 — Answering (Final Decision)
# Once a clear classification is reached, MediLLM announces the decision:
# - “Decision: Appointment Confirmed”
# - “Decision: Slot Unavailable, Please Reschedule”

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()

API_TOKEN = os.getenv('API_KEY_HUGG')
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 50
    }

    response = requests.post(API_URL, headers=headers, json=payload)

    if response.status_code != 200:
        return f"API Error {response.status_code}: {response.text}"

    try:
        data = response.json()
    except:
        return f"Non-JSON response: {response.text}"

    if "choices" in data:
        return data["choices"][0]["message"]["content"]

    return str(data)


def confirm_slot(request):
    return "Appointment Confirmed"


def suggest_reschedule(request):
    return "Slot Unavailable, Please Reschedule"


def appointment_agent(request: str):
    thought = query_llm(f"Analyze this appointment request: {request}")
    print("LLM Thought:", thought)

    if "10 am" in request.lower() or "booked" in request.lower():
        action = suggest_reschedule
    else:
        action = confirm_slot

    result = action(request)

    final_answer = query_llm(f"Decide if slop avaiable or not: {result}")
    return final_answer


print(appointment_agent("Request for Dr. Sharma at 10 AM tomorrow"))
print("\ n NEXT REQUEST\n")
print(appointment_agent("Request for Dr. Mehta at 4 PM tomorrow"))
# Out:
# LLM Thought: Here's an analysis of the appointment request:
#
# 1. **Specificity**: The request is specific about the doctor's name (Dr. Sharma) and the time of the appointment (10 AM).
# 2. **Schedule**: The request is specific about the
# Based on the information provided, the slot is currently unavailable. The message explicitly states "Slot Unavailable" and suggests "Please Reschedule". This implies that the slot has been booked, cancelled, or has some other issue, making it unavailable for use
# /n NEXT REQUEST/n
# LLM Thought: Analysis of the Appointment Request:
#
# 1. **Request Type:** The request is for an appointment with a medical professional, Dr. Mehta.
# 2. **Scheduling Details:**
#    - **Date:** The appointment is scheduled for tomorrow.
#    -
# Based on the given information, "Appointment Confirmed" does not directly imply the availability of soap (slop). However, considering the context, it is likely that the appointment is related to cleaning or maintenance, which might involve the availability of soap or
