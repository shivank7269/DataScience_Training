# %%
# Scenario:
# We want to classify whether a restaurant order is “Large” (1) or “Small” (0)
# based on the number of items ordered.
# If items ≥ 3 → Large order
# If items < 3 → Small order

import numpy as np
X = np.array([[1],
              [2],
              [3],
              [4]])

y = np.array([0,0,1,1])
np.random.seed(42)

weights = np.random.rand(1)
bias = np.random.rand(1)

learning_rate = 0.1

def activation(z):
    return 1 if z >= 0 else 0

# Step 4: Training Loop
for epoch in range(1,11):

    print(f"Epoch {epoch}")

    for i in range(len(X)):

        z = np.dot(X[i], weights) + bias
        y_pred = activation(z)

        error = y[i] - y_pred

        # Update weights and bias
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Items Ordered: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, Error: {error}")

    print("Updated Weight:", weights)
    print("Updated Bias:", bias)


# Step 5: Test the perceptron
print("\nTesting the Model")
test_orders = np.array([2,3,4])
for items in test_orders:
    z = np.dot(items, weights) + bias
    prediction = activation(z)
    print(f"Items Ordered: {items}, Prediction: {prediction}")
# Out:
# Epoch 1
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 1, Actual: 1, Error: 0
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.75071431]
# Epoch 2
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.65071431]
# Epoch 3
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.55071431]
# Epoch 4
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.45071431]
# Epoch 5
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.35071431]
# Epoch 6
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.25071431]
# Epoch 7
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.07454012]
# Updated Bias: [0.15071431]
# Epoch 8
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 0, Actual: 0, Error: 0
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.27454012]
# Updated Bias: [0.15071431]
# Epoch 9
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.27454012]
# Updated Bias: [0.05071431]
# Epoch 10
# Items Ordered: [1], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [2], Predicted: 1, Actual: 0, Error: -1
# Items Ordered: [3], Predicted: 0, Actual: 1, Error: 1
# Items Ordered: [4], Predicted: 1, Actual: 1, Error: 0
# Updated Weight: [0.27454012]
# Updated Bias: [-0.04928569]
#
# Testing the Model
# Items Ordered: 2, Prediction: 1
# Items Ordered: 3, Prediction: 1
# Items Ordered: 4, Prediction: 1
