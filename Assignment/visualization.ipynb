# %%
import numpy as np
import matplotlib.pyplot as plt
salaries = np.random.normal(50000,10000,1000)
plt.hist(salaries,bins=20,label='Salaries')
plt.xlabel('Salary')
plt.ylabel('freq')
plt.legend()

plt.show()
